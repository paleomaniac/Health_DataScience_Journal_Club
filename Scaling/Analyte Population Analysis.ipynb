# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("analyte_pop.csv")

# %%
df.head()
# Out:
#   country                    analyte  \
# 0      US                    alanine
# 1      US                   arginine
# 2      US  argininosuccinic aciduria
# 3      US                 asparagine
# 4      US              aspartic acid
#
#                                               Source   age    mean     sd  \
# 0  Serum Amino Acid Profiles in Normal Subjects a...  65.0  216.51  42.75
# 1  Serum Amino Acid Profiles in Normal Subjects a...  65.0   96.75  22.92
# 2  Serum Amino Acid Profiles in Normal Subjects a...  65.0    0.17   0.05
# 3  Serum Amino Acid Profiles in Normal Subjects a...  65.0     NaN    NaN
# 4  Serum Amino Acid Profiles in Normal Subjects a...  65.0   57.79  10.97
#
#    up_lim  low_lim    unit  Unnamed: 9  Unnamed: 10 Unnamed: 11
# 0     NaN      NaN  μmol/L         NaN          NaN         NaN
# 1     NaN      NaN  μmol/L         NaN          NaN         NaN
# 2     NaN      NaN  μmol/L         NaN          NaN         NaN
# ...

# %%
df.describe()
# Out:
#               age         mean           sd       up_lim       low_lim  \
# count  148.000000   141.000000    79.000000    83.000000     83.000000
# mean    54.446622   204.426922    74.488608   146.345675    285.999349
# std     11.457508   651.899391   301.654023   487.130654   1315.527387
# min     38.700000     0.150000     0.030000     0.000000      2.000000
# 25%     46.000000    31.910000     6.085000     7.200000     30.435500
# 50%     61.000000    82.000000    22.670000    45.775000     73.000000
# 75%     65.000000   197.050000    44.895000    97.950000    188.150000
# max     67.700000  7180.710000  2641.880000  4211.880000  12020.000000
#
#        Unnamed: 9  Unnamed: 10
# count         0.0          0.0
# mean          NaN          NaN
# std           NaN          NaN
# min           NaN          NaN
# 25%           NaN          NaN
# 50%           NaN          NaN
# 75%           NaN          NaN
# max           NaN          NaN

# %%
df_sort = df.sort_values(by = ['analyte','country'])

# %%
df_sort_clean = df_sort.replace(['aspartic acid'],'Aspartic acid')
df_sort_clean = df_sort.replace(['1-methylhistidine'],'1-Methylhistidine')
df_sort_clean = df_sort.replace(['1-methylhistidine'],'1-Methylhistidine')
df_sort_clean = df_sort.replace(['alanine'],'Alanine')

# %%
df['analyte'] = df['analyte'].str.lower()

# %%
sorted(df['analyte'].dropna())
# Out:
# ['1-methylhistidine',
#  '1-methylhistidine',
#  '3-methylhistidine',
#  '3-methylhistidine',
#  'alanine',
#  'alanine',
#  'alanine',
#  'alanine',
#  'alanine',
#  'alanine',
#  'arginine',
#  'arginine',
#  'arginine',
#  'arginine',
#  'arginine',
#  'arginine',
#  'argininosuccinic aciduria',
#  'asparagine',
#  'asparagine',
#  'asparagine',
#  'asparagine',
#  'aspartate',
#  'aspartic acid',
#  'aspartic acid',
#  'aspartic acid',
#  'aspartic acid',
#  'bcaa',
#  'citrulline',
#  'citrulline',
#  'citrulline',
#  'citrulline',
#  'citrulline',
#  'cystathionine',
#  'cystein',
#  'cysteine',
#  'cystine',
#  'cystine',
#  'cystine',
#  'eaa',
#  'ethanolamine',
#  'ethanolamine',
#  'formiminoglutamic acid',
#  'glutamic acid',
#  'glutamic acid',
#  'glutamic acid',
#  'glutamic acid',
#  'glutamic_acid',
#  'glutamine',
#  'glutamine',
#  'glutamine',
#  'glutamine',
#  'glutamine',
#  'glycine',
#  'glycine',
#  'glycine',
#  'glycine',
#  'glycine',
#  'glycine',
# ...

# %%
df = df.replace(['cystein'],'cysteine')
df = df.replace(['leucine(xle)'],'leucine')

# %%
df['analyte'].unique()
# Out:
# array(['alanine', 'arginine', 'argininosuccinic aciduria', 'asparagine',
#        'aspartic acid', 'citrulline', 'formiminoglutamic acid',
#        'glutamic acid', 'glutamine', 'glycine', 'histidine', 'homo-cit',
#        'isoleucine', 'leucine', 'methionine', 'ornithine',
#        'phenylalanine', 'serine', 'succinylacetone', 'tryptophan',
#        'tyrosine', 'valine', '1-methylhistidine', '3-methylhistidine',
#        'cystine', 'ethanolamine', 'hydroxyproline', 'lysine', 'proline',
#        'sarcosine', 'taurine', 'threonine', 'α-aminoadipic acid',
#        'α-amino-n-butyric acid', 'β-alanine', 'β-aminoisobutyric acid',
#        'α-aminobutyric acid', 'cystathionine', 'phosphoethanolamine',
#        'phosphoserine', 'aspartate', 'taa', 'eaa', 'bcaa', 'tryptophan ',
#        'cysteine', 'hydroxylysine ', 'glutamic_acid', nan], dtype=object)

# %%
for i in df['country']:
    print(i)
# Out:
# US
# US
# US
# US
# US
# US
# US
# US
# US
# US
# US
# US
# US
# US
# US
# US
# US
# US
# US
# US
# US
# US
# Poland
# Poland
# Poland
# Poland
# Poland
# Poland
# Poland
# Poland
# Poland
# Poland
# Poland
# Poland
# Poland
# Poland
# Poland
# Poland
# Poland
# Poland
# Poland
# Poland
# Poland
# Poland
# Poland
# Poland
# Poland
# Poland
# Poland
# Poland
# Poland
# Poland
# Poland
# Poland
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Singapore
# Canada(F)
# Canada(F)
# Canada(F)
# Canada(F)
# Canada(F)
# Canada(F)
# Canada(F)
# Canada(F)
# Canada(F)
# Canada(F)
# Canada(F)
# Canada(F)
# Canada(F)
# Canada(F)
# Canada(F)
# Canada(F)
# Canada(F)
# Canada(F)
# ...
